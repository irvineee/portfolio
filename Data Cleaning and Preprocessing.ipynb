# %%
import nltk
from nltk.tokenize import word_tokenize

# %%
import pandas as pd

# %%
fake_news = pd.read_csv("Fake.csv")
true_news = pd.read_csv("True.csv")

# %%
fake_news['label'] = 'fake'
true_news['label'] = 'real'

# %%
data = pd.concat([fake_news, true_news], axis=0)
data = data.sample(frac=1).reset_index(drop=True)
data.drop('subject', axis=1)
# Out:
#                                                    title  \
# 0      LEFTY MEDIA DESPERATELY Tries To Bury Trump Bu...
# 1       Snowflake Trump Demands An Apology From The M...
# 2      Illinois to sell bonds, but cannot tap all the...
# 3      COMEDY GOLD! Clinton Gaffe While Reading Off O...
# 4      KID ROCK’S INTERVIEW With Piers Morgan Sheds L...
# ...                                                  ...
# 44893   Trump Wants To Know Why Nobody Talked About R...
# 44894  WATCH: BLACK LIVES MATTER Bernie Sanders Suppo...
# 44895  EX-FBI AGENT NAVY SEAL: “Russian Interference”...
# 44896  SWEDISH WOMAN Sexually Assaulted In Broad Dayl...
# 44897  Neocon Nightmare: Trump Wants to ‘Get Along Wi...
#
#                                                     text               date  \
# 0      CNN political hack Alison Camarota wants to na...       Jun 16, 2017
# 1      Donald Trump went on a whining rant about the ...      June 13, 2017
# 2      CHICAGO (Reuters) - Illinois will sell $550 mi...     June 15, 2016
# 3      Hillary reads off of the teleprompter an emoti...       Jun 25, 2016
# 4      Former MI Supreme Court Justice and black cons...       Jul 22, 2017
# ...                                                  ...                ...
# 44893  Donald Trump has dismissed the CIA findings th...  December 12, 2016
# 44894  The new Democrat party Godless Socialists, rac...        Apr 4, 2016
# 44895  Former FBI Agent and Navy Seal Jonathan Gillia...       Dec 20, 2016
# 44896  Swedish resident, Rosa Vidarsdottir tells a ha...       Jul 30, 2016
# 44897  21st Century Wire says Could this be the real ...      March 4, 2016
#
#       label
# 0      fake
# 1      fake
# 2      real
# 3      fake
# 4      fake
# ...     ...
# 44893  fake
# 44894  fake
# 44895  fake
# 44896  fake
# 44897  fake
#
# [44898 rows x 4 columns]

# %%
data['news'] = data['title'] + ' ' + data['text']

# %%
#creates a new column and makes the title and text into lower case
data["title"] = data["title"].str.lower()
data["text"] = data["text"].str.lower()

#removes any urls that might be in the title or text
data["title"] = data["title"].str.replace('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', ' ')
data["text"] = data["text"].str.replace('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', ' ')

#splits up the text into an individual words in the list
data["title"] = data["title"].apply(word_tokenize)
data["text"] = data["text"].apply(word_tokenize)
# Out:
# /var/folders/89/qc704b414r390sdcdygd15tw0000gn/T/ipykernel_66059/24784212.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   data["title"] = data["title"].str.replace('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', ' ')
# /var/folders/89/qc704b414r390sdcdygd15tw0000gn/T/ipykernel_66059/24784212.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   data["text"] = data["text"].str.replace('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', ' ')

# %%
data
# Out:
#                                                    title  \
# 0      [lefty, media, desperately, tries, to, bury, t...
# 1      [snowflake, trump, demands, an, apology, from,...
# 2      [illinois, to, sell, bonds, ,, but, can, not, ...
# 3      [comedy, gold, !, clinton, gaffe, while, readi...
# 4      [kid, rock, ’, s, interview, with, piers, morg...
# ...                                                  ...
# 44893  [trump, wants, to, know, why, nobody, talked, ...
# 44894  [watch, :, black, lives, matter, bernie, sande...
# 44895  [ex-fbi, agent, navy, seal, :, “, russian, int...
# 44896  [swedish, woman, sexually, assaulted, in, broa...
# 44897  [neocon, nightmare, :, trump, wants, to, ‘, ge...
#
#                                                     text          subject  \
# 0      [cnn, political, hack, alison, camarota, wants...        left-news
# 1      [donald, trump, went, on, a, whining, rant, ab...             News
# 2      [chicago, (, reuters, ), -, illinois, will, se...     politicsNews
# 3      [hillary, reads, off, of, the, teleprompter, a...         politics
# 4      [former, mi, supreme, court, justice, and, bla...         politics
# ...                                                  ...              ...
# 44893  [donald, trump, has, dismissed, the, cia, find...             News
# 44894  [the, new, democrat, party, godless, socialist...         politics
# 44895  [former, fbi, agent, and, navy, seal, jonathan...  Government News
# 44896  [swedish, resident, ,, rosa, vidarsdottir, tel...        left-news
# 44897  [21st, century, wire, says, could, this, be, t...      Middle-east
#
#                     date label  \
# 0           Jun 16, 2017  fake
# 1          June 13, 2017  fake
# 2         June 15, 2016   real
# 3           Jun 25, 2016  fake
# 4           Jul 22, 2017  fake
# ...                  ...   ...
# 44893  December 12, 2016  fake
# 44894        Apr 4, 2016  fake
# 44895       Dec 20, 2016  fake
# 44896       Jul 30, 2016  fake
# 44897      March 4, 2016  fake
#
#                                                     news
# 0      LEFTY MEDIA DESPERATELY Tries To Bury Trump Bu...
# 1       Snowflake Trump Demands An Apology From The M...
# 2      Illinois to sell bonds, but cannot tap all the...
# 3      COMEDY GOLD! Clinton Gaffe While Reading Off O...
# 4      KID ROCK’S INTERVIEW With Piers Morgan Sheds L...
# ...                                                  ...
# 44893   Trump Wants To Know Why Nobody Talked About R...
# 44894  WATCH: BLACK LIVES MATTER Bernie Sanders Suppo...
# 44895  EX-FBI AGENT NAVY SEAL: “Russian Interference”...
# 44896  SWEDISH WOMAN Sexually Assaulted In Broad Dayl...
# 44897  Neocon Nightmare: Trump Wants to ‘Get Along Wi...
#
# [44898 rows x 6 columns]

# %%
# Contraction Splitting - Done
# Stemming - Done
# Lemmatization - Not needed
# Stop Word Removal - done

# %%
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/adhiau/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import re
# Initialize the stopwords
stoplist = stopwords.words('english')

vocab_size = 10000
corpus = []
ps = PorterStemmer() ## used for standardization of words

for i in range(0,len(data)):
    message = re.sub('[^a-zA-Z]',' ',data['news'][i]) ## except a-z and A-Z all charectors will be replaced by space
    message = message.lower() ## then make every words in lower
    message = message.split() ## then split every words in list
    
    message = [ps.stem(word) for word in message if not word in stoplist] ## use stem to stem words which are not in stoplist
    message = ' '.join(message) ## then join those words to make the full sentence as a list 
    corpus.append(message) ## then append all the sentences in the corpus

# %%
len(corpus)
# Out:
# 44898

# %%
for i in range(0,len(corpus)):
    data['clean_news'] = corpus

# %%
data
# Out:
#                                                    title  \
# 0      [lefty, media, desperately, tries, to, bury, t...
# 1      [snowflake, trump, demands, an, apology, from,...
# 2      [illinois, to, sell, bonds, ,, but, can, not, ...
# 3      [comedy, gold, !, clinton, gaffe, while, readi...
# 4      [kid, rock, ’, s, interview, with, piers, morg...
# ...                                                  ...
# 44893  [trump, wants, to, know, why, nobody, talked, ...
# 44894  [watch, :, black, lives, matter, bernie, sande...
# 44895  [ex-fbi, agent, navy, seal, :, “, russian, int...
# 44896  [swedish, woman, sexually, assaulted, in, broa...
# 44897  [neocon, nightmare, :, trump, wants, to, ‘, ge...
#
#                                                     text          subject  \
# 0      [cnn, political, hack, alison, camarota, wants...        left-news
# 1      [donald, trump, went, on, a, whining, rant, ab...             News
# 2      [chicago, (, reuters, ), -, illinois, will, se...     politicsNews
# 3      [hillary, reads, off, of, the, teleprompter, a...         politics
# 4      [former, mi, supreme, court, justice, and, bla...         politics
# ...                                                  ...              ...
# 44893  [donald, trump, has, dismissed, the, cia, find...             News
# 44894  [the, new, democrat, party, godless, socialist...         politics
# 44895  [former, fbi, agent, and, navy, seal, jonathan...  Government News
# 44896  [swedish, resident, ,, rosa, vidarsdottir, tel...        left-news
# 44897  [21st, century, wire, says, could, this, be, t...      Middle-east
#
#                     date label  \
# 0           Jun 16, 2017  fake
# 1          June 13, 2017  fake
# 2         June 15, 2016   real
# 3           Jun 25, 2016  fake
# 4           Jul 22, 2017  fake
# ...                  ...   ...
# 44893  December 12, 2016  fake
# 44894        Apr 4, 2016  fake
# 44895       Dec 20, 2016  fake
# 44896       Jul 30, 2016  fake
# 44897      March 4, 2016  fake
#
#                                                     news  \
# 0      LEFTY MEDIA DESPERATELY Tries To Bury Trump Bu...
# 1       Snowflake Trump Demands An Apology From The M...
# 2      Illinois to sell bonds, but cannot tap all the...
# 3      COMEDY GOLD! Clinton Gaffe While Reading Off O...
# 4      KID ROCK’S INTERVIEW With Piers Morgan Sheds L...
# ...                                                  ...
# 44893   Trump Wants To Know Why Nobody Talked About R...
# 44894  WATCH: BLACK LIVES MATTER Bernie Sanders Suppo...
# 44895  EX-FBI AGENT NAVY SEAL: “Russian Interference”...
# 44896  SWEDISH WOMAN Sexually Assaulted In Broad Dayl...
# 44897  Neocon Nightmare: Trump Wants to ‘Get Along Wi...
#
#                                               clean_news
# 0      lefti media desper tri buri trump brilliant ke...
# 1      snowflak trump demand apolog media internet la...
# 2      illinoi sell bond cannot tap proce chicago reu...
# 3      comedi gold clinton gaff read teleprompt darn ...
# 4      kid rock interview pier morgan shed light demo...
# ...                                                  ...
# 44893  trump want know nobodi talk russian hack elect...
# 44894  watch black live matter berni sander support s...
# 44895  ex fbi agent navi seal russian interfer lie sp...
# 44896  swedish woman sexual assault broad daylight mi...
# 44897  neocon nightmar trump want get along foreign c...
#
# [44898 rows x 7 columns]

# %%
import contractions

for i in range(0, len(data['clean_news'])):
    text = data['clean_news'][i]
    expanded_words = []   
    for word in text.split():
        # using contractions.fix to expand the shortened words
        expanded_words.append(contractions.fix(word))
    data['clean_news'][i] = expanded_words

# %%
data.to_csv('clean_data.csv')

# %%
len(data)
# Out:
# 44898

# %%
data2 = data.drop(['title', 'text', 'news'], axis = 1)

# %%
data2
data2.to_csv('clean_data2.csv')
